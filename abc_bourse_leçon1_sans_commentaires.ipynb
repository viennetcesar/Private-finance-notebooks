# %% [markdown]
# Ce notebook reprend le cours n°1 sur les tendances de abcbouse dont le lien vers la page est juste en dessous. Il est intéressant d'ouvrir le lien et de lirre la page avant de lancer les codes afin
# de mieux saisir les concepts de base
# https://www.abcbourse.com/apprendre/11_lecon1.html

# %%
# On importe une librairie qui permet de ne pas prendre en compte certaines erreurs un peu
# boring à traiter pendant notre code
import warnings
warnings.filterwarnings('ignore')

# %%
import yfinance as yf
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np
from sklearn.linear_model import LinearRegression
import plotly.graph_objects as go
from scipy.signal import argrelextrema
from datetime import date 

# on importe tous les modules (codes) qui nous simplifiront la vie
# et nous permettront de tracer des beaux graphiques
# faire des beaux tableaux etc...

# %%
url = 'https://en.wikipedia.org/wiki/List_of_S%26P_500_companies'
pd.read_html(url, header=0)[0]
# pd.read_html(url, header=0)[0]
# Out:
#     Symbol                                Security             GICS Sector  \
# 0      MMM                                      3M             Industrials
# 1      AOS                             A. O. Smith             Industrials
# 2      ABT                     Abbott Laboratories             Health Care
# 3     ABBV                                  AbbVie             Health Care
# 4      ACN                               Accenture  Information Technology
# 5     ADBE                              Adobe Inc.  Information Technology
# 6      AMD                  Advanced Micro Devices  Information Technology
# 7      AES                         AES Corporation               Utilities
# 8      AFL                                   Aflac              Financials
# 9        A                    Agilent Technologies             Health Care
# 10     APD                            Air Products               Materials
# 11    ABNB                                  Airbnb  Consumer Discretionary
# 12    AKAM                     Akamai Technologies  Information Technology
# 13     ALB                   Albemarle Corporation               Materials
# 14     ARE         Alexandria Real Estate Equities             Real Estate
# 15    ALGN                        Align Technology             Health Care
# 16    ALLE                                Allegion             Industrials
# 17     LNT                          Alliant Energy               Utilities
# 18     ALL                                Allstate              Financials
# 19   GOOGL                 Alphabet Inc. (Class A)  Communication Services
# 20    GOOG                 Alphabet Inc. (Class C)  Communication Services
# 21      MO                                  Altria        Consumer Staples
# 22    AMZN                                  Amazon  Consumer Discretionary
# 23    AMCR                                   Amcor               Materials
# 24    AMTM                                 Amentum             Industrials
# 25     AEE                                  Ameren               Utilities
# 26     AEP                 American Electric Power               Utilities
# 27     AXP                        American Express              Financials
# 28     AIG            American International Group              Financials
# 29     AMT                          American Tower             Real Estate
# 30     AWK                    American Water Works               Utilities
# 31     AMP                    Ameriprise Financial              Financials
# 32     AME                                  Ametek             Industrials
# 33    AMGN                                   Amgen             Health Care
# 34     APH                                Amphenol  Information Technology
# 35     ADI                          Analog Devices  Information Technology
# 36    ANSS                                   Ansys  Information Technology
# 37     AON                                     Aon              Financials
# 38     APA                         APA Corporation                  Energy
# 39    AAPL                              Apple Inc.  Information Technology
# 40    AMAT                       Applied Materials  Information Technology
# 41    APTV                                   Aptiv  Consumer Discretionary
# 42    ACGL                      Arch Capital Group              Financials
# 43     ADM                  Archer Daniels Midland        Consumer Staples
# 44    ANET                         Arista Networks  Information Technology
# 45     AJG               Arthur J. Gallagher & Co.              Financials
# 46     AIZ                                Assurant              Financials
# 47       T                                    AT&T  Communication Services
# 48     ATO                            Atmos Energy               Utilities
# 49    ADSK                                Autodesk  Information Technology
# 50     ADP               Automatic Data Processing             Industrials
# 51     AZO                                AutoZone  Consumer Discretionary
# 52     AVB                   AvalonBay Communities             Real Estate
# 53     AVY                          Avery Dennison               Materials
# 54    AXON                         Axon Enterprise             Industrials
# 55     BKR                            Baker Hughes                  Energy
# 56    BALL                        Ball Corporation               Materials
# 57     BAC                         Bank of America              Financials
# 58     BAX                    Baxter International             Health Care
# 59     BDX                        Becton Dickinson             Health Care
# 60   BRK.B                      Berkshire Hathaway              Financials
# 61     BBY                                Best Buy  Consumer Discretionary
# 62    TECH                              Bio-Techne             Health Care
# 63    BIIB                                  Biogen             Health Care
# 64     BLK                               BlackRock              Financials
# 65      BX                         Blackstone Inc.              Financials
# 66      BK                              BNY Mellon              Financials
# 67      BA                                  Boeing             Industrials
# 68    BKNG                        Booking Holdings  Consumer Discretionary
# 69     BWA                              BorgWarner  Consumer Discretionary
# 70     BSX                       Boston Scientific             Health Care
# 71     BMY                    Bristol Myers Squibb             Health Care
# 72    AVGO                                Broadcom  Information Technology
# 73      BR          Broadridge Financial Solutions             Industrials
# 74     BRO                           Brown & Brown              Financials
# 75    BF.B                            Brown–Forman        Consumer Staples
# 76    BLDR                    Builders FirstSource             Industrials
# 77      BG                            Bunge Global        Consumer Staples
# 78     BXP                               BXP, Inc.             Real Estate
# 79    CHRW                           C.H. Robinson             Industrials
# 80    CDNS                  Cadence Design Systems  Information Technology
# 81     CZR                   Caesars Entertainment  Consumer Discretionary
# 82     CPT                   Camden Property Trust             Real Estate
# 83     CPB                   Campbell Soup Company        Consumer Staples
# 84     COF                             Capital One              Financials
# 85     CAH                         Cardinal Health             Health Care
# 86     KMX                                  CarMax  Consumer Discretionary
# 87     CCL                                Carnival  Consumer Discretionary
# 88    CARR                          Carrier Global             Industrials
# 89     CAT                        Caterpillar Inc.             Industrials
# 90    CBOE                     Cboe Global Markets              Financials
# 91    CBRE                              CBRE Group             Real Estate
# 92     CDW                                     CDW  Information Technology
# 93      CE                                Celanese               Materials
# 94     COR                                 Cencora             Health Care
# 95     CNC                     Centene Corporation             Health Care
# 96     CNP                      CenterPoint Energy               Utilities
# 97      CF                           CF Industries               Materials
# 98     CRL              Charles River Laboratories             Health Care
# 99    SCHW              Charles Schwab Corporation              Financials
# 100   CHTR                  Charter Communications  Communication Services
# 101    CVX                     Chevron Corporation                  Energy
# 102    CMG                  Chipotle Mexican Grill  Consumer Discretionary
# 103     CB                           Chubb Limited              Financials
# 104    CHD                         Church & Dwight        Consumer Staples
# 105     CI                                   Cigna             Health Care
# 106   CINF                    Cincinnati Financial              Financials
# 107   CTAS                                  Cintas             Industrials
# 108   CSCO                                   Cisco  Information Technology
# 109      C                               Citigroup              Financials
# 110    CFG                Citizens Financial Group              Financials
# 111    CLX                                  Clorox        Consumer Staples
# 112    CME                               CME Group              Financials
# 113    CMS                              CMS Energy               Utilities
# 114     KO                 Coca-Cola Company (The)        Consumer Staples
# 115   CTSH                               Cognizant  Information Technology
# 116     CL                       Colgate-Palmolive        Consumer Staples
# 117  CMCSA                                 Comcast  Communication Services
# 118    CAG                          Conagra Brands        Consumer Staples
# 119    COP                          ConocoPhillips                  Energy
# 120     ED                     Consolidated Edison               Utilities
# 121    STZ                    Constellation Brands        Consumer Staples
# 122    CEG                    Constellation Energy               Utilities
# 123    COO                  Cooper Companies (The)             Health Care
# 124   CPRT                                  Copart             Industrials
# 125    GLW                            Corning Inc.  Information Technology
# 126   CPAY                                  Corpay              Financials
# 127   CTVA                                 Corteva               Materials
# 128   CSGP                            CoStar Group             Real Estate
# 129   COST                                  Costco        Consumer Staples
# 130   CTRA                                 Coterra                  Energy
# 131   CRWD                             CrowdStrike  Information Technology
# 132    CCI                            Crown Castle             Real Estate
# 133    CSX                         CSX Corporation             Industrials
# 134    CMI                                 Cummins             Industrials
# 135    CVS                              CVS Health             Health Care
# 136    DHR                     Danaher Corporation             Health Care
# 137    DRI                      Darden Restaurants  Consumer Discretionary
# 138    DVA                                  DaVita             Health Care
# 139    DAY                                Dayforce             Industrials
# 140   DECK                          Deckers Brands  Consumer Discretionary
# 141     DE                         Deere & Company             Industrials
# 142   DELL                       Dell Technologies  Information Technology
# 143    DAL                         Delta Air Lines             Industrials
# 144    DVN                            Devon Energy                  Energy
# 145   DXCM                                  Dexcom             Health Care
# 146   FANG                      Diamondback Energy                  Energy
# 147    DLR                          Digital Realty             Real Estate
# 148    DFS                      Discover Financial              Financials
# 149     DG                          Dollar General        Consumer Staples
# 150   DLTR                             Dollar Tree        Consumer Staples
# 151      D                         Dominion Energy               Utilities
# 152    DPZ                                Domino's  Consumer Discretionary
# 153    DOV                       Dover Corporation             Industrials
# 154    DOW                                Dow Inc.               Materials
# 155    DHI                            D. R. Horton  Consumer Discretionary
# 156    DTE                              DTE Energy               Utilities
# 157    DUK                             Duke Energy               Utilities
# 158     DD                                  DuPont               Materials
# 159    EMN                Eastman Chemical Company               Materials
# 160    ETN                       Eaton Corporation             Industrials
# 161   EBAY                                    eBay  Consumer Discretionary
# 162    ECL                                  Ecolab               Materials
# 163    EIX                    Edison International               Utilities
# 164     EW                    Edwards Lifesciences             Health Care
# 165     EA                         Electronic Arts  Communication Services
# 166    ELV                         Elevance Health             Health Care
# 167    EMR                        Emerson Electric             Industrials
# 168   ENPH                          Enphase Energy  Information Technology
# 169    ETR                                 Entergy               Utilities
# 170    EOG                           EOG Resources                  Energy
# 171   EPAM                            EPAM Systems  Information Technology
# 172    EQT                         EQT Corporation                  Energy
# 173    EFX                                 Equifax             Industrials
# 174   EQIX                                 Equinix             Real Estate
# 175    EQR                      Equity Residential             Real Estate
# 176   ERIE                          Erie Indemnity              Financials
# 177    ESS                    Essex Property Trust             Real Estate
# 178     EL            Estée Lauder Companies (The)        Consumer Staples
# 179     EG                           Everest Group              Financials
# 180   EVRG                                  Evergy               Utilities
# 181     ES                       Eversource Energy               Utilities
# 182    EXC                                  Exelon               Utilities
# 183   EXPE                           Expedia Group  Consumer Discretionary
# 184   EXPD                Expeditors International             Industrials
# 185    EXR                     Extra Space Storage             Real Estate
# 186    XOM                              ExxonMobil                  Energy
# 187   FFIV                                F5, Inc.  Information Technology
# 188    FDS                                 FactSet              Financials
# 189   FICO                              Fair Isaac  Information Technology
# 190   FAST                                Fastenal             Industrials
# 191    FRT         Federal Realty Investment Trust             Real Estate
# 192    FDX                                   FedEx             Industrials
# 193    FIS  Fidelity National Information Services              Financials
# 194   FITB                     Fifth Third Bancorp              Financials
# 195   FSLR                             First Solar  Information Technology
# 196     FE                             FirstEnergy               Utilities
# 197     FI                                  Fiserv              Financials
# 198    FMC                         FMC Corporation               Materials
# 199      F                      Ford Motor Company  Consumer Discretionary
# 200   FTNT                                Fortinet  Information Technology
# 201    FTV                                 Fortive             Industrials
# 202   FOXA               Fox Corporation (Class A)  Communication Services
# 203    FOX               Fox Corporation (Class B)  Communication Services
# 204    BEN                      Franklin Resources              Financials
# 205    FCX                        Freeport-McMoRan               Materials
# 206   GRMN                                  Garmin  Consumer Discretionary
# 207     IT                                 Gartner  Information Technology
# 208     GE                            GE Aerospace             Industrials
# 209   GEHC                           GE HealthCare             Health Care
# 210    GEV                              GE Vernova             Industrials
# 211    GEN                             Gen Digital  Information Technology
# 212   GNRC                                 Generac             Industrials
# 213     GD                        General Dynamics             Industrials
# 214    GIS                           General Mills        Consumer Staples
# 215     GM                          General Motors  Consumer Discretionary
# 216    GPC                   Genuine Parts Company  Consumer Discretionary
# 217   GILD                         Gilead Sciences             Health Care
# 218    GPN                         Global Payments              Financials
# 219     GL                              Globe Life              Financials
# 220   GDDY                                 GoDaddy  Information Technology
# 221     GS                           Goldman Sachs              Financials
# 222    HAL                             Halliburton                  Energy
# 223    HIG                          Hartford (The)              Financials
# 224    HAS                                  Hasbro  Consumer Discretionary
# 225    HCA                          HCA Healthcare             Health Care
# 226    DOC                   Healthpeak Properties             Real Estate
# 227   HSIC                            Henry Schein             Health Care
# 228    HSY                   Hershey Company (The)        Consumer Staples
# 229    HES                        Hess Corporation                  Energy
# 230    HPE              Hewlett Packard Enterprise  Information Technology
# 231    HLT                        Hilton Worldwide  Consumer Discretionary
# 232   HOLX                                 Hologic             Health Care
# 233     HD                        Home Depot (The)  Consumer Discretionary
# 234    HON                               Honeywell             Industrials
# 235    HRL                            Hormel Foods        Consumer Staples
# 236    HST                   Host Hotels & Resorts             Real Estate
# 237    HWM                        Howmet Aerospace             Industrials
# 238    HPQ                                 HP Inc.  Information Technology
# 239   HUBB                    Hubbell Incorporated             Industrials
# 240    HUM                                  Humana             Health Care
# 241   HBAN                   Huntington Bancshares              Financials
# 242    HII           Huntington Ingalls Industries             Industrials
# 243    IBM                                     IBM  Information Technology
# 244    IEX                        IDEX Corporation             Industrials
# 245   IDXX                      Idexx Laboratories             Health Care
# 246    ITW                     Illinois Tool Works             Industrials
# 247   INCY                                  Incyte             Health Care
# 248     IR                          Ingersoll Rand             Industrials
# 249   PODD                     Insulet Corporation             Health Care
# 250   INTC                                   Intel  Information Technology
# 251    ICE               Intercontinental Exchange              Financials
# 252    IFF      International Flavors & Fragrances               Materials
# 253     IP                     International Paper               Materials
# 254    IPG    Interpublic Group of Companies (The)  Communication Services
# 255   INTU                                  Intuit  Information Technology
# 256   ISRG                      Intuitive Surgical             Health Care
# 257    IVZ                                 Invesco              Financials
# 258   INVH                        Invitation Homes             Real Estate
# 259    IQV                                   IQVIA             Health Care
# 260    IRM                           Iron Mountain             Real Estate
# 261   JBHT                               J.B. Hunt             Industrials
# 262    JBL                                   Jabil  Information Technology
# 263   JKHY                 Jack Henry & Associates              Financials
# 264      J                        Jacobs Solutions             Industrials
# 265    JNJ                       Johnson & Johnson             Health Care
# 266    JCI                        Johnson Controls             Industrials
# 267    JPM                          JPMorgan Chase              Financials
# 268   JNPR                        Juniper Networks  Information Technology
# 269      K                               Kellanova        Consumer Staples
# 270   KVUE                                  Kenvue        Consumer Staples
# 271    KDP                        Keurig Dr Pepper        Consumer Staples
# 272    KEY                                 KeyCorp              Financials
# 273   KEYS                   Keysight Technologies  Information Technology
# 274    KMB                          Kimberly-Clark        Consumer Staples
# 275    KIM                            Kimco Realty             Real Estate
# 276    KMI                           Kinder Morgan                  Energy
# 277    KKR                                     KKR              Financials
# 278   KLAC                         KLA Corporation  Information Technology
# 279    KHC                             Kraft Heinz        Consumer Staples
# 280     KR                                  Kroger        Consumer Staples
# 281    LHX                                L3Harris             Industrials
# 282     LH                                 LabCorp             Health Care
# 283   LRCX                            Lam Research  Information Technology
# 284     LW                             Lamb Weston        Consumer Staples
# 285    LVS                         Las Vegas Sands  Consumer Discretionary
# 286   LDOS                                  Leidos             Industrials
# 287    LEN                                  Lennar  Consumer Discretionary
# 288    LLY                             Lilly (Eli)             Health Care
# 289    LIN                               Linde plc               Materials
# 290    LYV               Live Nation Entertainment  Communication Services
# 291    LKQ                         LKQ Corporation  Consumer Discretionary
# 292    LMT                         Lockheed Martin             Industrials
# 293      L                       Loews Corporation              Financials
# 294    LOW                                  Lowe's  Consumer Discretionary
# 295   LULU                     Lululemon Athletica  Consumer Discretionary
# 296    LYB                          LyondellBasell               Materials
# 297    MTB                                M&T Bank              Financials
# 298    MPC                      Marathon Petroleum                  Energy
# 299   MKTX                             MarketAxess              Financials
# 300    MAR                  Marriott International  Consumer Discretionary
# 301    MMC                          Marsh McLennan              Financials
# 302    MLM               Martin Marietta Materials               Materials
# 303    MAS                                   Masco             Industrials
# 304     MA                              Mastercard              Financials
# 305   MTCH                             Match Group  Communication Services
# 306    MKC                     McCormick & Company        Consumer Staples
# 307    MCD                              McDonald's  Consumer Discretionary
# 308    MCK                    McKesson Corporation             Health Care
# 309    MDT                               Medtronic             Health Care
# 310    MRK                             Merck & Co.             Health Care
# 311   META                          Meta Platforms  Communication Services
# 312    MET                                 MetLife              Financials
# 313    MTD                          Mettler Toledo             Health Care
# 314    MGM                             MGM Resorts  Consumer Discretionary
# 315   MCHP                    Microchip Technology  Information Technology
# 316     MU                       Micron Technology  Information Technology
# 317   MSFT                               Microsoft  Information Technology
# 318    MAA       Mid-America Apartment Communities             Real Estate
# 319   MRNA                                 Moderna             Health Care
# 320    MHK                       Mohawk Industries  Consumer Discretionary
# 321    MOH                       Molina Healthcare             Health Care
# 322    TAP           Molson Coors Beverage Company        Consumer Staples
# 323   MDLZ                  Mondelez International        Consumer Staples
# 324   MPWR                Monolithic Power Systems  Information Technology
# 325   MNST                        Monster Beverage        Consumer Staples
# 326    MCO                     Moody's Corporation              Financials
# 327     MS                          Morgan Stanley              Financials
# 328    MOS                    Mosaic Company (The)               Materials
# 329    MSI                      Motorola Solutions  Information Technology
# 330   MSCI                                    MSCI              Financials
# 331   NDAQ                            Nasdaq, Inc.              Financials
# 332   NTAP                                  NetApp  Information Technology
# 333   NFLX                                 Netflix  Communication Services
# 334    NEM                                 Newmont               Materials
# 335   NWSA                     News Corp (Class A)  Communication Services
# 336    NWS                     News Corp (Class B)  Communication Services
# 337    NEE                          NextEra Energy               Utilities
# 338    NKE                              Nike, Inc.  Consumer Discretionary
# 339     NI                                NiSource               Utilities
# 340   NDSN                     Nordson Corporation             Industrials
# 341    NSC                Norfolk Southern Railway             Industrials
# 342   NTRS                          Northern Trust              Financials
# 343    NOC                        Northrop Grumman             Industrials
# 344   NCLH          Norwegian Cruise Line Holdings  Consumer Discretionary
# 345    NRG                              NRG Energy               Utilities
# 346    NUE                                   Nucor               Materials
# 347   NVDA                                  Nvidia  Information Technology
# 348    NVR                               NVR, Inc.  Consumer Discretionary
# 349   NXPI                      NXP Semiconductors  Information Technology
# 350   ORLY                     O'Reilly Auto Parts  Consumer Discretionary
# 351    OXY                    Occidental Petroleum                  Energy
# 352   ODFL                            Old Dominion             Industrials
# 353    OMC                           Omnicom Group  Communication Services
# 354     ON                        ON Semiconductor  Information Technology
# 355    OKE                                   ONEOK                  Energy
# 356   ORCL                      Oracle Corporation  Information Technology
# 357   OTIS                          Otis Worldwide             Industrials
# 358   PCAR                                  Paccar             Industrials
# 359    PKG        Packaging Corporation of America               Materials
# 360   PLTR                   Palantir Technologies  Information Technology
# 361   PANW                      Palo Alto Networks  Information Technology
# 362   PARA                        Paramount Global  Communication Services
# 363     PH                         Parker Hannifin             Industrials
# 364   PAYX                                 Paychex             Industrials
# 365   PAYC                                  Paycom             Industrials
# 366   PYPL                                  PayPal              Financials
# 367    PNR                                 Pentair             Industrials
# 368    PEP                                 PepsiCo        Consumer Staples
# 369    PFE                                  Pfizer             Health Care
# 370    PCG                        PG&E Corporation               Utilities
# 371     PM             Philip Morris International        Consumer Staples
# 372    PSX                             Phillips 66                  Energy
# 373    PNW                           Pinnacle West               Utilities
# 374    PNC                  PNC Financial Services              Financials
# 375   POOL                        Pool Corporation  Consumer Discretionary
# 376    PPG                          PPG Industries               Materials
# 377    PPL                         PPL Corporation               Utilities
# 378    PFG               Principal Financial Group              Financials
# 379     PG                        Procter & Gamble        Consumer Staples
# 380    PGR                 Progressive Corporation              Financials
# 381    PLD                                Prologis             Real Estate
# 382    PRU                    Prudential Financial              Financials
# 383    PEG         Public Service Enterprise Group               Utilities
# 384    PTC                                PTC Inc.  Information Technology
# 385    PSA                          Public Storage             Real Estate
# 386    PHM                              PulteGroup  Consumer Discretionary
# 387   QRVO                                   Qorvo  Information Technology
# 388    PWR                         Quanta Services             Industrials
# 389   QCOM                                Qualcomm  Information Technology
# 390    DGX                       Quest Diagnostics             Health Care
# 391     RL                Ralph Lauren Corporation  Consumer Discretionary
# 392    RJF                 Raymond James Financial              Financials
# 393    RTX                         RTX Corporation             Industrials
# 394      O                           Realty Income             Real Estate
# 395    REG                         Regency Centers             Real Estate
# 396   REGN               Regeneron Pharmaceuticals             Health Care
# 397     RF           Regions Financial Corporation              Financials
# 398    RSG                       Republic Services             Industrials
# 399    RMD                                  ResMed             Health Care
# 400   RVTY                                 Revvity             Health Care
# 401    ROK                     Rockwell Automation             Industrials
# 402    ROL                           Rollins, Inc.             Industrials
# 403    ROP                      Roper Technologies  Information Technology
# 404   ROST                             Ross Stores  Consumer Discretionary
# 405    RCL                   Royal Caribbean Group  Consumer Discretionary
# 406   SPGI                              S&P Global              Financials
# 407    CRM                              Salesforce  Information Technology
# 408   SBAC                      SBA Communications             Real Estate
# 409    SLB                            Schlumberger                  Energy
# 410    STX                      Seagate Technology  Information Technology
# 411    SRE                                  Sempra               Utilities
# 412    NOW                              ServiceNow  Information Technology
# 413    SHW                        Sherwin-Williams               Materials
# 414    SPG                    Simon Property Group             Real Estate
# 415   SWKS                      Skyworks Solutions  Information Technology
# 416    SJM              J.M. Smucker Company (The)        Consumer Staples
# 417     SW                        Smurfit WestRock               Materials
# 418    SNA                                 Snap-on             Industrials
# 419   SOLV                               Solventum             Health Care
# 420     SO                        Southern Company               Utilities
# 421    LUV                      Southwest Airlines             Industrials
# 422    SWK                  Stanley Black & Decker             Industrials
# 423   SBUX                               Starbucks  Consumer Discretionary
# 424    STT                State Street Corporation              Financials
# 425   STLD                          Steel Dynamics               Materials
# 426    STE                                  Steris             Health Care
# 427    SYK                     Stryker Corporation             Health Care
# 428   SMCI                              Supermicro  Information Technology
# 429    SYF                     Synchrony Financial              Financials
# 430   SNPS                                Synopsys  Information Technology
# 431    SYY                                   Sysco        Consumer Staples
# 432   TMUS                             T-Mobile US  Communication Services
# 433   TROW                           T. Rowe Price              Financials
# 434   TTWO                    Take-Two Interactive  Communication Services
# 435    TPR                          Tapestry, Inc.  Consumer Discretionary
# 436   TRGP                         Targa Resources                  Energy
# 437    TGT                      Target Corporation        Consumer Staples
# 438    TEL                         TE Connectivity  Information Technology
# 439    TDY                   Teledyne Technologies  Information Technology
# 440    TFX                                Teleflex             Health Care
# 441    TER                                Teradyne  Information Technology
# 442   TSLA                             Tesla, Inc.  Consumer Discretionary
# 443    TXN                       Texas Instruments  Information Technology
# 444    TPL          Texas Pacific Land Corporation                  Energy
# 445    TXT                                 Textron             Industrials
# 446    TMO                Thermo Fisher Scientific             Health Care
# 447    TJX                           TJX Companies  Consumer Discretionary
# 448   TSCO                          Tractor Supply  Consumer Discretionary
# 449     TT                      Trane Technologies             Industrials
# 450    TDG                         TransDigm Group             Industrials
# 451    TRV               Travelers Companies (The)              Financials
# 452   TRMB                            Trimble Inc.  Information Technology
# 453    TFC                        Truist Financial              Financials
# 454    TYL                      Tyler Technologies  Information Technology
# 455    TSN                             Tyson Foods        Consumer Staples
# 456    USB                            U.S. Bancorp              Financials
# 457   UBER                                    Uber             Industrials
# 458    UDR                               UDR, Inc.             Real Estate
# 459   ULTA                             Ulta Beauty  Consumer Discretionary
# 460    UNP               Union Pacific Corporation             Industrials
# 461    UAL                United Airlines Holdings             Industrials
# 462    UPS                   United Parcel Service             Industrials
# 463    URI                          United Rentals             Industrials
# 464    UNH                      UnitedHealth Group             Health Care
# 465    UHS               Universal Health Services             Health Care
# 466    VLO                           Valero Energy                  Energy
# 467    VTR                                  Ventas             Real Estate
# 468   VLTO                                 Veralto             Industrials
# 469   VRSN                                Verisign  Information Technology
# 470   VRSK                        Verisk Analytics             Industrials
# 471     VZ                                 Verizon  Communication Services
# 472   VRTX                  Vertex Pharmaceuticals             Health Care
# 473   VTRS                                 Viatris             Health Care
# 474   VICI                         Vici Properties             Real Estate
# 475      V                               Visa Inc.              Financials
# 476    VST                            Vistra Corp.               Utilities
# 477    VMC                Vulcan Materials Company               Materials
# 478    WRB               W. R. Berkley Corporation              Financials
# 479    GWW                          W. W. Grainger             Industrials
# 480    WAB                                  Wabtec             Industrials
# 481    WBA                Walgreens Boots Alliance        Consumer Staples
# 482    WMT                                 Walmart        Consumer Staples
# 483    DIS               Walt Disney Company (The)  Communication Services
# 484    WBD                  Warner Bros. Discovery  Communication Services
# 485     WM                        Waste Management             Industrials
# 486    WAT                      Waters Corporation             Health Care
# 487    WEC                        WEC Energy Group               Utilities
# 488    WFC                             Wells Fargo              Financials
# 489   WELL                               Welltower             Real Estate
# 490    WST            West Pharmaceutical Services             Health Care
# 491    WDC                         Western Digital  Information Technology
# 492     WY                            Weyerhaeuser             Real Estate
# 493    WMB                      Williams Companies                  Energy
# 494    WTW                    Willis Towers Watson              Financials
# 495   WYNN                            Wynn Resorts  Consumer Discretionary
# 496    XEL                             Xcel Energy               Utilities
# 497    XYL                              Xylem Inc.             Industrials
# 498    YUM                             Yum! Brands  Consumer Discretionary
# 499   ZBRA                      Zebra Technologies  Information Technology
# 500    ZBH                           Zimmer Biomet             Health Care
# 501    ZTS                                  Zoetis             Health Care
#
#                                      GICS Sub-Industry  \
# 0                             Industrial Conglomerates
# 1                                    Building Products
# 2                                Health Care Equipment
# 3                                        Biotechnology
# 4                       IT Consulting & Other Services
# 5                                 Application Software
# 6                                       Semiconductors
# 7         Independent Power Producers & Energy Traders
# 8                              Life & Health Insurance
# 9                       Life Sciences Tools & Services
# 10                                    Industrial Gases
# 11                      Hotels, Resorts & Cruise Lines
# 12                  Internet Services & Infrastructure
# 13                                 Specialty Chemicals
# 14                                        Office REITs
# 15                                Health Care Supplies
# 16                                   Building Products
# 17                                  Electric Utilities
# 18                       Property & Casualty Insurance
# 19                        Interactive Media & Services
# 20                        Interactive Media & Services
# 21                                             Tobacco
# 22                                    Broadline Retail
# 23      Paper & Plastic Packaging Products & Materials
# 24                        Diversified Support Services
# 25                                     Multi-Utilities
# 26                                  Electric Utilities
# 27                                    Consumer Finance
# 28                                Multi-line Insurance
# 29                                 Telecom Tower REITs
# 30                                     Water Utilities
# 31                    Asset Management & Custody Banks
# 32                   Electrical Components & Equipment
# 33                                       Biotechnology
# 34                               Electronic Components
# 35                                      Semiconductors
# 36                                Application Software
# 37                                   Insurance Brokers
# 38                  Oil & Gas Exploration & Production
# 39          Technology Hardware, Storage & Peripherals
# 40                 Semiconductor Materials & Equipment
# 41                        Automotive Parts & Equipment
# 42                       Property & Casualty Insurance
# 43                    Agricultural Products & Services
# 44                            Communications Equipment
# 45                                   Insurance Brokers
# 46                                Multi-line Insurance
# 47               Integrated Telecommunication Services
# 48                                       Gas Utilities
# 49                                Application Software
# 50                Human Resource & Employment Services
# 51                                   Automotive Retail
# 52                      Multi-Family Residential REITs
# 53      Paper & Plastic Packaging Products & Materials
# 54                                 Aerospace & Defense
# 55                      Oil & Gas Equipment & Services
# 56                   Metal, Glass & Plastic Containers
# 57                                   Diversified Banks
# 58                               Health Care Equipment
# 59                               Health Care Equipment
# 60                               Multi-Sector Holdings
# 61                       Computer & Electronics Retail
# 62                      Life Sciences Tools & Services
# 63                                       Biotechnology
# 64                    Asset Management & Custody Banks
# 65                    Asset Management & Custody Banks
# 66                    Asset Management & Custody Banks
# 67                                 Aerospace & Defense
# 68                      Hotels, Resorts & Cruise Lines
# 69                        Automotive Parts & Equipment
# 70                               Health Care Equipment
# 71                                     Pharmaceuticals
# 72                                      Semiconductors
# 73               Data Processing & Outsourced Services
# 74                                   Insurance Brokers
# 75                               Distillers & Vintners
# 76                                   Building Products
# 77                    Agricultural Products & Services
# 78                                        Office REITs
# 79                             Air Freight & Logistics
# 80                                Application Software
# 81                                    Casinos & Gaming
# 82                      Multi-Family Residential REITs
# 83                              Packaged Foods & Meats
# 84                                    Consumer Finance
# 85                            Health Care Distributors
# 86                                   Automotive Retail
# 87                      Hotels, Resorts & Cruise Lines
# 88                                   Building Products
# 89   Construction Machinery & Heavy Transportation ...
# 90                          Financial Exchanges & Data
# 91                                Real Estate Services
# 92                             Technology Distributors
# 93                                 Specialty Chemicals
# 94                            Health Care Distributors
# 95                                 Managed Health Care
# 96                                     Multi-Utilities
# 97                Fertilizers & Agricultural Chemicals
# 98                      Life Sciences Tools & Services
# 99                      Investment Banking & Brokerage
# 100                                  Cable & Satellite
# 101                               Integrated Oil & Gas
# 102                                        Restaurants
# 103                      Property & Casualty Insurance
# 104                                 Household Products
# 105                               Health Care Services
# 106                      Property & Casualty Insurance
# 107                       Diversified Support Services
# 108                           Communications Equipment
# 109                                  Diversified Banks
# 110                                     Regional Banks
# 111                                 Household Products
# 112                         Financial Exchanges & Data
# 113                                    Multi-Utilities
# 114              Soft Drinks & Non-alcoholic Beverages
# 115                     IT Consulting & Other Services
# 116                                 Household Products
# 117                                  Cable & Satellite
# 118                             Packaged Foods & Meats
# 119                 Oil & Gas Exploration & Production
# 120                                    Multi-Utilities
# 121                              Distillers & Vintners
# 122                                 Electric Utilities
# 123                               Health Care Supplies
# 124                       Diversified Support Services
# 125                              Electronic Components
# 126          Transaction & Payment Processing Services
# 127               Fertilizers & Agricultural Chemicals
# 128                               Real Estate Services
# 129                Consumer Staples Merchandise Retail
# 130                 Oil & Gas Exploration & Production
# 131                                   Systems Software
# 132                                Telecom Tower REITs
# 133                                Rail Transportation
# 134  Construction Machinery & Heavy Transportation ...
# 135                               Health Care Services
# 136                     Life Sciences Tools & Services
# 137                                        Restaurants
# 138                               Health Care Services
# 139               Human Resource & Employment Services
# 140                                           Footwear
# 141                      Agricultural & Farm Machinery
# 142         Technology Hardware, Storage & Peripherals
# 143                                 Passenger Airlines
# 144                 Oil & Gas Exploration & Production
# 145                              Health Care Equipment
# 146                 Oil & Gas Exploration & Production
# 147                                  Data Center REITs
# 148                                   Consumer Finance
# 149                Consumer Staples Merchandise Retail
# ...
# 169                                      1913
# 170                                      1999
# 171                                      1993
# 172                                      1888
# 173                                      1899
# 174                                      1998
# 175                                      1969
# 176                                      1925
# 177                                      1971
# 178                                      1946
# 179                                      1973
# 180                                      1909
# 181                                      1966
# 182                                      2000
# 183                                      1996
# 184                                      1979
# 185                                      1977
# 186                                      1999
# 187                                      1996
# 188                                      1978
# 189                                      1956
# 190                                      1967
# 191                                      1962
# 192                                      1971
# 193                                      1968
# 194                                      1858
# 195                                      1999
# 196                                      1997
# 197                                      1984
# 198                                      1883
# 199                                      1903
# 200                                      2000
# 201                                      2016
# 202                                      2019
# 203                                      2019
# 204                                      1947
# 205                                      1912
# 206                                      1989
# 207                                      1979
# 208                                      1892
# 209                                      1994
# 210                                      2024
# 211                                      1982
# 212                                      1959
# 213                                      1899
# 214                                      1856
# 215                                      1908
# 216                                      1925
# 217                                      1987
# 218                                      2000
# 219                                      1900
# 220                                      1997
# 221                                      1869
# 222                                      1919
# 223                                      1810
# 224                                      1923
# 225                                      1968
# 226                                      1985
# 227                                      1932
# 228                                      1894
# 229                                      1919
# 230                                      2015
# 231                                      1919
# 232                                      1985
# 233                                      1978
# 234                                      1906
# 235                                      1891
# 236                                      1993
# 237                                      1888
# 238                               1939 (2015)
# 239                                      1888
# 240                                      1961
# 241                                      1866
# 242                                      2011
# 243                                      1911
# 244                                      1988
# 245                                      1983
# 246                                      1912
# 247                                      1991
# 248                                      1859
# 249                                      2000
# 250                                      1968
# 251                                      2000
# 252                               1958 (1889)
# 253                                      1898
# 254                               1961 (1930)
# 255                                      1983
# 256                                      1995
# 257                                      1935
# 258                                      2012
# 259                                      1982
# 260                                      1951
# 261                                      1961
# 262                                      1966
# 263                                      1976
# 264                                      1947
# 265                                      1886
# 266                                      1885
# 267                        2000 (1799 / 1871)
# 268                                      1996
# 269                                      1906
# 270          2022 (Johnson & Johnson spinoff)
# 271                                      1981
# 272                                      1825
# 273                               2014 (1939)
# 274                                      1872
# 275                                      1958
# 276                                      1997
# 277                                      1976
# 278                          1975/1977 (1997)
# 279                               2015 (1869)
# 280                                      1883
# 281               2019 (L3 1997, Harris 1895)
# 282                                      1978
# 283                                      1980
# 284                               2016 (1950)
# 285                                      1988
# 286                                      1969
# 287                                      1954
# 288                                      1876
# 289                                      1879
# 290                                      2010
# 291                                      1998
# 292                                      1995
# 293                                      1959
# 294                            1904/1946/1959
# 295                                      1998
# 296                                      2007
# 297                                      1856
# 298                               2009 (1887)
# 299                                      2000
# 300                                      1927
# 301                                      1905
# 302                                      1993
# 303                                      1929
# 304                                      1966
# 305                                      1986
# 306                                      1889
# 307                                      1940
# 308                                      1833
# 309                                      1949
# 310                                      1891
# 311                                      2004
# 312                                      1868
# 313                                      1945
# 314                                      1986
# 315                                      1989
# 316                                      1978
# 317                                      1975
# 318                                      1977
# 319                                      2010
# 320                                      1878
# 321                                      1980
# 322            2005 (Molson 1786, Coors 1873)
# 323                                      2012
# 324                                      1997
# 325                               2012 (1935)
# 326                                      1909
# 327                                      1935
# 328                        2004 (1865 / 1909)
# 329                               1928 (2011)
# 330                                      1969
# 331                                      1971
# 332                                      1992
# 333                                      1997
# 334                                      1921
# 335              2013 (News Corporation 1980)
# 336              2013 (News Corporation 1980)
# 337                               1984 (1925)
# 338                                      1964
# 339                                      1912
# 340                                      1935
# 341                          1881/1894 (1980)
# 342                                      1889
# 343        1994 (Northrop 1939, Grumman 1930)
# 344                               2011 (1966)
# 345                                      1992
# 346                                      1940
# 347                                      1993
# 348                                      1980
# 349                                      1953
# 350                                      1957
# 351                                      1920
# 352                                      1934
# 353                                      1986
# 354                                      1999
# 355                                      1906
# 356                                      1977
# 357  2020 (1853, United Technologies spinoff)
# 358                                      1905
# 359                                      1959
# 360                                      2003
# 361                                      2005
# 362            2019 (Paramount Pictures 1912)
# 363                                      1917
# 364                                      1971
# 365                                      1998
# 366                                      1998
# 367                                      1966
# 368                                      1898
# 369                                      1849
# 370                                      1905
# 371                               2008 (1847)
# 372                               2012 (1917)
# 373                                      1985
# 374                                      1845
# 375                                      1993
# 376                                      1883
# 377                                      1920
# 378                                      1879
# 379                                      1837
# 380                                      1937
# 381                                      1983
# 382                                      1875
# 383                                      1903
# 384                                      1985
# 385                                      1972
# 386                                      1956
# 387                                      2015
# 388                                      1997
# 389                                      1985
# 390                                      1967
# 391                                      1967
# 392                                      1962
# 393                                      1922
# 394                                      1969
# 395                                      1963
# 396                                      1988
# 397                                      1971
# 398                               1998 (1981)
# 399                                      1989
# 400                                      1937
# 401                                      1903
# 402                                      1948
# 403                                      1981
# 404                                      1982
# 405                                      1997
# 406                                      1917
# 407                                      1999
# 408                                      1989
# 409                                      1926
# 410                                      1979
# 411                                      1998
# 412                                      2003
# 413                                      1866
# 414                                      2003
# 415                                      2002
# 416                                      1897
# 417                                      1934
# 418                                      1920
# 419                                      2023
# 420                                      1945
# 421                                      1967
# 422                                      1843
# 423                                      1971
# 424                                      1792
# 425                                      1993
# 426                                      1985
# 427                                      1941
# 428                                      1993
# 429                                      2003
# 430                                      1986
# 431                                      1969
# 432                                      1994
# 433                                      1937
# 434                                      1993
# 435                                      2017
# 436                                      2005
# 437                                      1902
# 438                                      2007
# 439                                      1960
# 440                                      1943
# 441                                      1960
# 442                                      2003
# 443                                      1930
# 444                                      1888
# 445                                      1923
# 446                               2006 (1902)
# 447                                      1987
# 448                                      1938
# 449                                      1871
# 450                                      1993
# 451                                      1853
# 452                                      1978
# 453                                      1872
# 454                                      1966
# 455                                      1935
# 456                                      1968
# 457                                      2009
# 458                                      1972
# 459                                      1990
# 460                                      1862
# 461                                      1967
# 462                                      1907
# 463                                      1997
# 464                                      1977
# 465                                      1979
# 466                                      1980
# 467                                      1998
# 468                                      2023
# 469                                      1995
# 470                                      1971
# 471                               1983 (1877)
# 472                                      1989
# 473                                      1961
# 474                                      2017
# 475                                      1958
# 476                                      2016
# 477                                      1909
# 478                                      1967
# 479                                      1927
# 480                               1999 (1869)
# 481                                      2014
# 482                                      1962
# 483                                      1923
# 484                  2022 (Warner Bros. 1923)
# 485                                      1968
# 486                                      1958
# 487                                      1896
# 488                                      1852
# 489                                      1970
# 490                                      1923
# 491                                      1970
# 492                                      1900
# 493                                      1908
# 494                                      2016
# 495                                      2002
# 496                                      1909
# 497                                      2011
# 498                                      1997
# 499                                      1969
# 500                                      1927
# 501                                      1952

# %%
# Ici on récupère sur wikipedia la liste des entreprises du Standard And Poor
# ainsi que les tickers (nom de l'entreprise sur le marché)
# par exemple AMZN pour Amazon

url = 'https://en.wikipedia.org/wiki/List_of_S%26P_500_companies' # le lien wikipedia
df = pd.read_html(url, header=0)[0] # on extrait le tableau de wikipedia
liste_tickers = df['Symbol'].to_list() # on transforme les tickers du tableau en une 'liste'
liste_tickers # on affiche cette liste avec tous les tickers
# Out:
# ['MMM',
#  'AOS',
#  'ABT',
#  'ABBV',
#  'ACN',
#  'ADBE',
#  'AMD',
#  'AES',
#  'AFL',
#  'A',
#  'APD',
#  'ABNB',
#  'AKAM',
#  'ALB',
#  'ARE',
#  'ALGN',
#  'ALLE',
#  'LNT',
#  'ALL',
#  'GOOGL',
#  'GOOG',
#  'MO',
#  'AMZN',
#  'AMCR',
#  'AMTM',
#  'AEE',
#  'AEP',
#  'AXP',
#  'AIG',
#  'AMT',
#  'AWK',
#  'AMP',
#  'AME',
#  'AMGN',
#  'APH',
#  'ADI',
#  'ANSS',
#  'AON',
#  'APA',
#  'AAPL',
#  'AMAT',
#  'APTV',
#  'ACGL',
#  'ADM',
#  'ANET',
#  'AJG',
#  'AIZ',
#  'T',
#  'ATO',
#  'ADSK',
#  'ADP',
#  'AZO',
#  'AVB',
#  'AVY',
#  'AXON',
#  'BKR',
#  'BALL',
#  'BAC',
#  'BAX',
#  'BDX',
#  'BRK.B',
#  'BBY',
#  'TECH',
#  'BIIB',
#  'BLK',
#  'BX',
#  'BK',
#  'BA',
#  'BKNG',
#  'BWA',
#  'BSX',
#  'BMY',
#  'AVGO',
#  'BR',
#  'BRO',
#  'BF.B',
#  'BLDR',
#  'BG',
#  'BXP',
#  'CHRW',
#  'CDNS',
#  'CZR',
#  'CPT',
#  'CPB',
#  'COF',
#  'CAH',
#  'KMX',
#  'CCL',
#  'CARR',
#  'CAT',
#  'CBOE',
#  'CBRE',
#  'CDW',
#  'CE',
#  'COR',
#  'CNC',
#  'CNP',
#  'CF',
#  'CRL',
#  'SCHW',
#  'CHTR',
#  'CVX',
#  'CMG',
#  'CB',
#  'CHD',
#  'CI',
#  'CINF',
#  'CTAS',
#  'CSCO',
#  'C',
#  'CFG',
#  'CLX',
#  'CME',
#  'CMS',
#  'KO',
#  'CTSH',
#  'CL',
#  'CMCSA',
#  'CAG',
#  'COP',
#  'ED',
#  'STZ',
#  'CEG',
#  'COO',
#  'CPRT',
#  'GLW',
#  'CPAY',
#  'CTVA',
#  'CSGP',
#  'COST',
#  'CTRA',
#  'CRWD',
#  'CCI',
#  'CSX',
#  'CMI',
#  'CVS',
#  'DHR',
#  'DRI',
#  'DVA',
#  'DAY',
#  'DECK',
#  'DE',
#  'DELL',
#  'DAL',
#  'DVN',
#  'DXCM',
#  'FANG',
#  'DLR',
#  'DFS',
#  'DG',
#  'DLTR',
#  'D',
#  'DPZ',
#  'DOV',
#  'DOW',
#  'DHI',
#  'DTE',
#  'DUK',
#  'DD',
#  'EMN',
#  'ETN',
#  'EBAY',
#  'ECL',
#  'EIX',
#  'EW',
#  'EA',
#  'ELV',
#  'EMR',
#  'ENPH',
#  'ETR',
#  'EOG',
#  'EPAM',
#  'EQT',
#  'EFX',
#  'EQIX',
#  'EQR',
#  'ERIE',
#  'ESS',
#  'EL',
#  'EG',
#  'EVRG',
#  'ES',
#  'EXC',
#  'EXPE',
#  'EXPD',
#  'EXR',
#  'XOM',
#  'FFIV',
#  'FDS',
#  'FICO',
#  'FAST',
#  'FRT',
#  'FDX',
#  'FIS',
#  'FITB',
#  'FSLR',
#  'FE',
#  'FI',
#  'FMC',
#  'F',
#  'FTNT',
#  'FTV',
#  'FOXA',
#  'FOX',
#  'BEN',
#  'FCX',
#  'GRMN',
#  'IT',
#  'GE',
#  'GEHC',
#  'GEV',
#  'GEN',
#  'GNRC',
#  'GD',
#  'GIS',
#  'GM',
#  'GPC',
#  'GILD',
#  'GPN',
#  'GL',
#  'GDDY',
#  'GS',
#  'HAL',
#  'HIG',
#  'HAS',
#  'HCA',
#  'DOC',
#  'HSIC',
#  'HSY',
#  'HES',
#  'HPE',
#  'HLT',
#  'HOLX',
#  'HD',
#  'HON',
#  'HRL',
#  'HST',
#  'HWM',
#  'HPQ',
#  'HUBB',
#  'HUM',
#  'HBAN',
#  'HII',
#  'IBM',
#  'IEX',
#  'IDXX',
#  'ITW',
#  'INCY',
#  'IR',
#  'PODD',
#  'INTC',
#  'ICE',
#  'IFF',
#  'IP',
#  'IPG',
#  'INTU',
#  'ISRG',
#  'IVZ',
#  'INVH',
#  'IQV',
#  'IRM',
#  'JBHT',
#  'JBL',
#  'JKHY',
#  'J',
#  'JNJ',
#  'JCI',
#  'JPM',
#  'JNPR',
#  'K',
#  'KVUE',
#  'KDP',
#  'KEY',
#  'KEYS',
#  'KMB',
#  'KIM',
#  'KMI',
#  'KKR',
#  'KLAC',
#  'KHC',
#  'KR',
#  'LHX',
#  'LH',
#  'LRCX',
#  'LW',
#  'LVS',
#  'LDOS',
#  'LEN',
#  'LLY',
#  'LIN',
#  'LYV',
#  'LKQ',
#  'LMT',
#  'L',
#  'LOW',
#  'LULU',
#  'LYB',
#  'MTB',
#  'MPC',
#  'MKTX',
#  'MAR',
#  'MMC',
#  'MLM',
#  'MAS',
#  'MA',
#  'MTCH',
#  'MKC',
#  'MCD',
#  'MCK',
#  'MDT',
#  'MRK',
#  'META',
#  'MET',
#  'MTD',
#  'MGM',
#  'MCHP',
#  'MU',
#  'MSFT',
#  'MAA',
#  'MRNA',
#  'MHK',
#  'MOH',
#  'TAP',
#  'MDLZ',
#  'MPWR',
#  'MNST',
#  'MCO',
#  'MS',
#  'MOS',
#  'MSI',
#  'MSCI',
#  'NDAQ',
#  'NTAP',
#  'NFLX',
#  'NEM',
#  'NWSA',
#  'NWS',
#  'NEE',
#  'NKE',
#  'NI',
#  'NDSN',
#  'NSC',
#  'NTRS',
#  'NOC',
#  'NCLH',
#  'NRG',
#  'NUE',
#  'NVDA',
#  'NVR',
#  'NXPI',
#  'ORLY',
#  'OXY',
#  'ODFL',
#  'OMC',
#  'ON',
#  'OKE',
#  'ORCL',
#  'OTIS',
#  'PCAR',
#  'PKG',
#  'PLTR',
#  'PANW',
#  'PARA',
#  'PH',
#  'PAYX',
#  'PAYC',
#  'PYPL',
#  'PNR',
#  'PEP',
#  'PFE',
#  'PCG',
#  'PM',
#  'PSX',
#  'PNW',
#  'PNC',
#  'POOL',
#  'PPG',
#  'PPL',
#  'PFG',
#  'PG',
#  'PGR',
#  'PLD',
#  'PRU',
#  'PEG',
#  'PTC',
#  'PSA',
#  'PHM',
#  'QRVO',
#  'PWR',
#  'QCOM',
#  'DGX',
#  'RL',
#  'RJF',
#  'RTX',
#  'O',
#  'REG',
#  'REGN',
#  'RF',
#  'RSG',
#  'RMD',
#  'RVTY',
#  'ROK',
#  'ROL',
#  'ROP',
#  'ROST',
#  'RCL',
#  'SPGI',
#  'CRM',
#  'SBAC',
#  'SLB',
#  'STX',
#  'SRE',
#  'NOW',
#  'SHW',
#  'SPG',
#  'SWKS',
#  'SJM',
#  'SW',
#  'SNA',
#  'SOLV',
#  'SO',
#  'LUV',
#  'SWK',
#  'SBUX',
#  'STT',
#  'STLD',
#  'STE',
#  'SYK',
#  'SMCI',
#  'SYF',
#  'SNPS',
#  'SYY',
#  'TMUS',
#  'TROW',
#  'TTWO',
#  'TPR',
#  'TRGP',
#  'TGT',
#  'TEL',
#  'TDY',
#  'TFX',
#  'TER',
#  'TSLA',
#  'TXN',
#  'TPL',
#  'TXT',
#  'TMO',
#  'TJX',
#  'TSCO',
#  'TT',
#  'TDG',
#  'TRV',
#  'TRMB',
#  'TFC',
#  'TYL',
#  'TSN',
#  'USB',
#  'UBER',
#  'UDR',
#  'ULTA',
#  'UNP',
#  'UAL',
#  'UPS',
#  'URI',
#  'UNH',
#  'UHS',
#  'VLO',
#  'VTR',
#  'VLTO',
#  'VRSN',
#  'VRSK',
#  'VZ',
#  'VRTX',
#  'VTRS',
#  'VICI',
#  'V',
#  'VST',
#  'VMC',
#  'WRB',
#  'GWW',
#  'WAB',
#  'WBA',
#  'WMT',
#  'DIS',
#  'WBD',
#  'WM',
#  'WAT',
#  'WEC',
#  'WFC',
#  'WELL',
#  'WST',
#  'WDC',
#  'WY',
#  'WMB',
#  'WTW',
#  'WYNN',
#  'XEL',
#  'XYL',
#  'YUM',
#  'ZBRA',
#  'ZBH',
#  'ZTS']

# %%
# On utilise le module datetime qui nous permet d'obtenir la date du jour
# à chaque fois qu'on lancera le code avec la méthode date.today()
aujourdhui = date.today()
date_formatee = aujourdhui.strftime("%Y-%m-%d") # on met au bon format la date pour qu'elle soit exploitable dans la suite du code 
date_formatee

# On s'intéresse ici à GOOGLE et dans la liste des tockers récupérée sur wikipedia dans la cellule
# de code précédente, on voit que GOOGLE est identifié en bourse par le ticker GOOGL
# on va donc mettre ce ticker dans une variable pour pouvoir le réutiliser autant de fois
# qu'on veut par la suite 
symbole = 'GOOGL'

# avec le module yahoo finance importé sous le nom de 'yf'
# on crée un objet Ticker et on lui donne le symbole GOOGL 
# cet objet contient un ensemble d'informations sur l'entreprise qu'on lui donne entre paranthèses
ticker = yf.Ticker(symbole)

# à partir de cet objet on va récupérer en particulier la série du cours de bourse avec la méthode
# .history, il faut préciser la date de début souhaitée et la date de fin
# c'est là qu'entre en jeu pour la date de fin notre variable 'date_formatee' qui rappelez vous
# contient la date d'aujourd'hui (jour où vous lancez le code sur votre ordinateur)
data = ticker.history(start='2023-06-27',
                     end=date_formatee)

# une fois le dataset des cours de bourse crée, nous sélectionnons en particulier la colonne
# qui contient le cours de clôture. En finance, il est commun d'utiliser le cours de clôture
# pour certaines méthodes d'évaluation
data = data[['Close']]

# %% [markdown]
# ### Tracer une bande de résistance

# %%
# On utilise le module datetime qui nous permet d'obtenir la date du jour
# à chaque fois qu'on lancera le code avec la méthode date.today()
aujourdhui = date.today()
date_formatee = aujourdhui.strftime("%Y-%m-%d") # on met au bon format la date pour qu'elle soit exploitable dans la suite du code 
date_formatee

symbole = 'GOOGL'  # on créee une variable qui contient le ticker de GOOGLE

ticker = yf.Ticker(symbole) # On créee un objet ticker qui contient un plein d'informations sur GOOGLE

# Dans cet objet ticker on peut par exemple récupérer les cours de bourse de GOOGLE
# sur une période au choix qu'on précise dans la fonction 'history' qui contient l'historique 
# des données de marché de GOOGLE
# on précise la date de début de notre choix dans 'start'
# on précise la date de fin de notre choix dans 'end'
data = ticker.history(start='2023-06-27',
                     end=date_formatee)  

# si vous lancez le code data.head() vous verrez que dans l'objet 'data' nous avons plusieurs cours
# comme le cours d'ouverture, le cours le plus haut, le cours le plus bas ...
# Nous sélectionnons seulement le cours de clôture nommé 'Close'
data = data[['Close']]

# %%
n = 10  # Comparaison avec les n voisins de chaque côté
local_max = argrelextrema(data['Close'].values, np.greater, order=n)[0]
# argrelextrema : Cette fonction de scipy.signal 
# identifie les indices des maximums locaux dans une série de données. (où ils se trouvent)
# la série donnée ici c'est data['Close'].values
# np.greater : Cherche les points où la valeur est supérieure aux voisins, identifiant ainsi les maximums
# order=n : Spécifie le nombre de points de chaque côté à comparer pour déterminer un maximum local
# local_max est alors une liste qui contient un tableau qui lui_même contient les indices
# avec le sélecteur [0] on choisit le premier élément de cette liste, à savoir le tableau lui-même
# qui contient les indices
# récap : on utilise une fonction qui prend les extrêmes on lui dit prends moi les extrêmes les plus
# hauts, on lui précise combien de points elle doit comparer pour choisir les plus hauts


# Sélectionner les 6 maximums locaux les plus élevés
# en réalité ici c'est vous qui choisissez le nombre de maximums locaux à relier par une droite
# un classique un peu arbitraire étant que si vous pouvez tracer une ligne entre 3 maximums
# locaux, celà signifie que le cours de bourse a frappé 3 fois une bande de résistance
# cette bande apparaît comme assez solide et difficile à percer, 
# en conséquence si le cours de bourse vient traverser (dépasser) cette bande alors on peut
# raisonnablement penser qu'il va continuer de monter car il vient de franchir un seuil de résistance
# installé depuis un moment déjà

# Maintenant on a les indices des points les plus hauts
# on va donc créer un mini dataframe avec ces seuls points les plus hauts
# ici on sélectionne dans le data frame les points les plus hauts avec le code 
# data['Close'].iloc[local_max]
# Des maximum locaux il y en a plus que 6 dans le mini data frame ici avec la méthode .nlargest(6)
# on ne garde que les 6 plus grands
selected_max = data['Close'].iloc[local_max].nlargest(17)

# Tracer les cours de l'action
plt.figure(figsize=(14, 7)) # on choisit les dimensions du cadre, du graphique
plt.plot(data.index, data['Close'], label='Cours de clôture') # on trace la figure en donnant
# à la fonction plot la valeur de l'axe des abscisses (data.index), la valeur des ordonnées, data['Close']
# et un nom au graphique label='Cours de clôture'

# Tracer la ligne de résistance à travers les trois points sélectionnés
# .index permet de sélectionner la date
# .value permet de sélectionner la valeur (le cours de bourse)
# 'ro' signifie qu'on veut tracer des points rouges (red o)
# 'r--' signifie qu'on veut tracer une ligne en tirets --------- et 'r' signifie 'red' pour rouge
plt.plot(selected_max.index, selected_max.values, 'ro', label='Maxima locaux') 
plt.plot(selected_max.index, selected_max.values, 'r--', label='Résistance')

# Ajouter des titres et légendes
# le xlabel est le titre de l'axe des 'x', des abscisses
# le ylabel est le titre de l'axe des 'y' , des ordonnées
plt.title(f'Cours de l\'action {ticker.ticker} avec bande de résistance')
plt.xlabel('Date')
plt.ylabel('Prix de clôture')
plt.legend()
plt.show()

# %% [markdown]
# ### Tous les points sont reliés sur le graphique du dessus mais on aimerait plutôt avoir 2 bandes de résistances distinctes alors nous allons séparer dans le code qui suit les 3 points qui permettront d'obtenir la bande de résistance de gauche et les 3 points qui permettront d'obtenir la bande de résistance de droite

# %%
# Pour séparer nos points on créer 2 objets différents de type Series
# car le type Series nous permettra plus facilement de garder la Date et le cours
# pour le moment ces objets sont vides, on va les remplir dans la suite du code
max_locaux1 = pd.Series()
max_locaux2 = pd.Series()

# il est l'heure de remplir ces 2 objets max_locaux1 et max_locaux2
# pour ce faire on fait une boucle qui itère sur selected_max qui rappelez vous contient
# tous les max_locaux
# et on dit : si le cours est plus petit que 160 tu me mets les max locaux dans la variable
# max_locaux1, si ils sont plus grands que 160 alors tu les mets dans la variable max_locaux2
# précisons que la méthode .at[index] permet de dire à l'objet Series que l'index qu'on avait
# dans la variable selected_max (la date) doit aussi être l'index dans la variable max_locaux
for index, valeur in selected_max.items():
    if valeur < 160:
        max_locaux1.at[index] = valeur
    else:
        max_locaux2.at[index] = valeur

# Affichage des résultats si vous voulez regarder ce que contiennent vos listes
# décommentez les 2 lignes de code suivantes et lancez le code de la cellule vous verrez à quoi
# ressemblent max_locaux1 et 2
# print('max_locaux1 (valeurs < 160):\n', max_locaux1)
# print('\nmax_locaux2 (valeurs >= 160):\n', max_locaux2)


# Tracer le graphique
plt.figure(figsize=(14, 7))
plt.plot(data.index, data['Close'], label='Cours de clôture')

# Tracer les points correspondant aux maxima locaux
# et les lignes qui les relient pour max_locaux1
plt.plot(max_locaux1.index, max_locaux1.values, 'bo', label='Maxima locaux < 160')
plt.plot(max_locaux1.index, max_locaux1.values, linestyle= '--', color='blue', label='Bande résistance 1')


# Tracer les points correspondant aux maxima locaux
# et les lignes qui les relient pour max_locaux2
plt.plot(max_locaux2.index, max_locaux2.values, 'ro', label='Maxima locaux > 160')
plt.plot(max_locaux2.index, max_locaux2.values, linestyle= '--',  color='red', label='Bande résistance 2')


# Ajouter des titres et légendes
plt.title('Cours de l\'action avec bandes de résistance')
plt.xlabel('Date')
plt.ylabel('Prix de clôture')
plt.legend()
plt.grid(True) # Ajouter une grille
plt.show() # Afficher le tout

# %% [markdown]
# ### Plus qu'à tout reprendre avec les min locaux pour tracer le support

# %%
n = 15  # Comparaison avec les n voisins de chaque côté
local_min = argrelextrema(data['Close'].values, np.less, order=n)[0]
# argrelextrema : Cette fonction de scipy.signal 
# identifie les indices des maximums locaux dans une série de données. (où ils se trouvent)
# la série donnée ici c'est data['Close'].values
# np.greater : Cherche les points où la valeur est supérieure aux voisins, identifiant ainsi les maximums
# order=n : Spécifie le nombre de points de chaque côté à comparer pour déterminer un maximum local
# local_max est alors une liste qui contient un tableau qui lui_même contient les indices
# avec le sélecteur [0] on choisit le premier élément de cette liste, à savoir le tableau lui-même
# qui contient les indices
# récap : on utilise une fonction qui prend les extrêmes on lui dit prends moi les extrêmes les plus
# hauts, on lui précise combien de points elle doit comparer pour choisir les plus hauts


# Sélectionner les 6 maximums locaux les plus élevés
# en réalité ici c'est vous qui choisissez le nombre de maximums locaux à relier par une droite
# un classique un peu arbitraire étant que si vous pouvez tracer une ligne entre 3 maximums
# locaux, celà signifie que le cours de bourse a frappé 3 fois une bande de résistance
# cette bande apparaît comme assez solide et difficile à percer, 
# en conséquence si le cours de bourse vient traverser (dépasser) cette bande alors on peut
# raisonnablement penser qu'il va continuer de monter car il vient de franchir un seuil de résistance
# installé depuis un moment déjà

# Maintenant on a les indices des points les plus bas
# on va donc créer un mini dataframe avec ces seuls points les plus bas
# ici on sélectionne dans le data frame les points les plus bas avec le code 
# data['Close'].iloc[local_min]
# Des minima locaux il y en a plus que 6 dans le mini data frame ici avec la méthode .nsmallest(6)
# on ne garde que les 6 plus petits
selected_min = data['Close'].iloc[local_min].nsmallest(6)

# Tracer les cours de l'action
plt.figure(figsize=(14, 7)) # on choisit les dimensions du cadre, du graphique
plt.plot(data.index, data['Close'], label='Cours de clôture') # on trace la figure en donnant
# à la fonction plot la valeur de l'axe des abscisses (data.index), la valeur des ordonnées, data['Close']
# et un nom au graphique label='Cours de clôture'

# Tracer la bande support à travers points sélectionnés
# .index permet de sélectionner la date
# .value permet de sélectionner la valeur (le cours de bourse)
# 'ro' signifie qu'on veut tracer des points rouges (red o)
# 'r--' signifie qu'on veut tracer une ligne en tirets --------- et 'r' signifie 'red' pour rouge
plt.plot(selected_min.index, selected_min.values, 'ro', label='Minima locaux') 
plt.plot(selected_min.index, selected_min.values, 'r--', label='Résistance')

# Ajouter des titres et légendes
# le xlabel est le titre de l'axe des 'x', des abscisses
# le ylabel est le titre de l'axe des 'y' , des ordonnées
plt.title(f'Cours de l\'action {ticker.ticker} avec bande de support')
plt.xlabel('Date')
plt.ylabel('Prix de clôture')
plt.legend()
plt.show()

# %%
# Il est possible de voir à l'oeil nu une bande support plus ou moins évidente qui est touchée 3 fois
# si on considères les 6 points minima locaux tracés ci-dessus
# Pour relier les points de cette bande qui démarre le 10/07/2023 et se termine le 06/03/2024
# Nous devons sélectionner seulement les 3 points qui une fois reliés constitueraient une bande de 
# support, à savoir le cours de bourse du 10/07/2023, celui du 27/10/2023 et celui du 06/03/2024
# Pour celà commençons par order la liste des minima_locaux selon la date (ordre temporel classique)
# la méthode .sort_index() permet de trier ('sort' signifie trier en Anglais) par l'index
# l'index étant la date dans notre cas, la variable selected_min sera triée par date de la plus 
# ancienne à la plus récente
selected_min = selected_min.sort_index()

# On créer un objet Series vide dans lequel on va ajouter nos 3 dates d'intérêt pour tracer
# la bande support
points_bande_support = pd.Series()

# Ensuite sélectionnons les points que nous souhaitons garder pour tracer la bande support
for index, valeur in selected_min.items():
    if str(index) in ['2023-07-10 00:00:00-04:00', '2023-10-27 00:00:00-04:00', '2024-03-06 00:00:00-05:00']:
        points_bande_support.at[index] = valeur

print(points_bande_support)
# Out:
# 2023-07-10 00:00:00-04:00    116.029381
# 2023-10-27 00:00:00-04:00    121.728722
# 2024-03-06 00:00:00-05:00    130.925369
# dtype: float64

# %% [markdown]
# ### à présent on a notre liste avec les 3 points de la bande support, il est temps de tracer cette bande stratégique

# %%
# On réprend exactement le code du graphique précédent mais cette fois-ci avec le traçage de la bande
# support qui comporte seulement nos 3 points sélectionnées

plt.figure(figsize=(14, 7)) # on choisit les dimensions du cadre, du graphique
plt.plot(data.index, data['Close'], label='Cours de clôture') # on trace la figure en donnant
# à la fonction plot la valeur de l'axe des abscisses (data.index), la valeur des ordonnées, data['Close']
# et un nom au graphique label='Cours de clôture'

# Tracer la bande support à travers les points sélectionnés
# .index permet de sélectionner la date
# .value permet de sélectionner la valeur (le cours de bourse)
# 'ro' signifie qu'on veut tracer des points rouges (red o)
# 'r--' signifie qu'on veut tracer une ligne en tirets --------- et 'r' signifie 'red' pour rouge
plt.plot(points_bande_support.index, points_bande_support.values, 'ro', label='Minima locaux') 
plt.plot(points_bande_support.index, points_bande_support.values, 'r--', label='Résistance')

# Ajouter des titres et légendes
# le xlabel est le titre de l'axe des 'x', des abscisses
# le ylabel est le titre de l'axe des 'y' , des ordonnées
plt.title(f'Cours de l\'action {ticker.ticker} avec bande de support')
plt.xlabel('Date')
plt.ylabel('Prix de clôture')
plt.legend()
plt.show()

# %% [markdown]
# ### Il nous reste à tout rassembler sur un seul et même graphique

# %%
plt.figure(figsize=(14, 7)) 
plt.plot(data.index, data['Close'], label='Cours de clôture') 

plt.plot(points_bande_support.index, points_bande_support.values, 'ro', label='Minima locaux') 
plt.plot(points_bande_support.index, points_bande_support.values, 'r--', label='Résistance')


plt.plot(max_locaux1.index, max_locaux1.values, 'bo', label='Maxima locaux < 160')
plt.plot(max_locaux1.index, max_locaux1.values, linestyle= '--', color='blue', label='Bande résistance 1')


plt.plot(max_locaux2.index, max_locaux2.values, 'bo', label='Maxima locaux > 160')
plt.plot(max_locaux2.index, max_locaux2.values, linestyle= '--',  color='blue', label='Bande résistance 2')

plt.title(f'Cours de l\'action {ticker.ticker} avec bande de support')
plt.xlabel('Date')
plt.ylabel('Prix de clôture')
plt.legend()
plt.show()

# %% [markdown]
# ### Maintenant que vous avez bien travaillé, je dois vous annoncer la nouvelle... On peut aussi tracer une droite de régression qui va vous donner la tendance linéaire du cours de bourse, et ensuite drifter cette droite de régression vers le haut jusqu'à ce que plusieurs points la touchent. Si le cours de bourse tape plusieurs fois cette bande et finit par la traverser à la hausse, l'idée est que la tendance est vraiment montante (au moins dans le court terme) et donc il faut tout de suite acheter l'action lorsque la barre est percée à la hausse.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import yfinance as yf
from datetime import date
from sklearn.linear_model import LinearRegression
import numpy as np

# Formatage de la date
aujourdhui = date.today()
date_formatee = aujourdhui.strftime("%Y-%m-%d")

# Ticker de GOOGLE
symbole = 'GOOGL'
ticker = yf.Ticker(symbole) # Création de l'objet ticker
data = ticker.history(start='2023-06-27', end=date_formatee)

# Conversion de la colonne 'Date' en datetime, plus pratique parfois pour manipuler les données
data.index = pd.to_datetime(data.index)




# data['MoyenneMobile_20_jours'] = data['Low'].rolling(window=20).mean()

# Ici on prend les Minimums de sur une fenêtre de 20 jours en partant du dernier cour observé
# puis on décale la fenêtre de 1 jour en arrière et on prend le min des 20 jours sur cette 
# nouvelle fenêtre, puis on décale la fenêtre de 1 jour en arrière et on prend le min des 20 jours
# sur cette fenêtre etc... etc... on peut bien sur change la fenêtre (3jours, 10jours ...)
# on fait ça pour garder seulement quelques minimums pertinents pour tracer un belle régression
# un régression qui matche un peu mieux aux MIN, toutefois vous pouvez aussi réaliser une régression
# sur toute la série des MIN, ça donnera un droite correcte avec des petits biais à cause
# des fortes variations de cette série
data['Low'] = data['Low'].rolling(window=20, min_periods=1).min()

# Préparation des données pour la régression
X = np.arange(len(data)).reshape(-1, 1)  # on génère des valeurs pour l'axe horizontal pour 
# pouvoir avoir des valeur pour X pour calculer la régression
# Concernant le reshape(-1,1) le -1 c'est pour dire : "ajuste moi automatiquement le bon nombre de lignes"
# autrement dit je veux autant de lignes dans mon vecteur X que de données dans mon dataframe
# et le 1 c'est pour dire que la variable X doit avoir une seule colonne
# résumé : je veux que X ait 1 colonne et len(data) lignes

# Les valeurs de Y sont les valeurs minimales 'Low' du cour de bourse lissées avec la moyenne mobile
y = data['Low']  # Valeurs des creux locaux

# Création et ajustement de la régression linéaire
model = LinearRegression().fit(X, y)

# Prédiction pour la bande de support
resistance = model.predict(X)

# Tracer le graphique
plt.figure(figsize=(10, 6))
plt.plot(data.index, data['High'], label='Prix Haut', color='black') # Utilise l'index pour les dates

# Tracer les bandes de support
# plt.plot(data.index, data['MoyenneMobile_20_jours'] , color='green', label='Moyenne mobile 20')
plt.plot(data.index, resistance + 17, linestyle='-', color='red', label='Ligne Haute de Support')
plt.plot(data.index, resistance - 7, linestyle='-', color='blue', label='Ligne Basse de Support')

plt.xlabel('Date')
plt.ylabel('Cour')
plt.title(f"Lignes de Support pour {symbole}")
plt.legend()
plt.show()
# Sur le graphique vous remarquez que fin avril la bande rouge est percée à la hausse, à ce moment
# Il fallait acheter. Le bon moment pour vendre est toujours difficile à détecter, cependant
# Il existe d'autres méthodes en analyse technique pour sentir et détecter le retournement

# %%
# On force l'affichage de toutes les lignes du tableau (un détail)
pd.set_option('display.max_rows', None)

# On encapsule dans une variable la droite de résistance qu'on avait tracée précédemment
# et on lui donne un nom clair et explicite : resistance haute
# puis on transforme cette simple variable en dataframe pour plus de simplicité dans la manipulation
# des données
resistance_haute = resistance + 17
df_resistance_haute = pd.DataFrame({'Résistance haute': resistance_haute}, index=data.index)



# à présent on concatène les 2 dataframes pour avoir dans la colonne de gauche le cour de bourse
# et dans la colonne de droite les valeur de la bande de résistance haute
df_concat = pd.concat([data['High'], df_resistance_haute], axis=1)

# On compare les colonnes pour savoir quand la résistance haute est percée par la série
# c'est à dire trouve le moment où la valeur du cour de bourse dépasse la valeur de la résistance
# autrement dit selon la leçon, le moment où il faut acheter car on pressent que le cour de l'action
# dévrait monter plus fortement que d'habitude étant donné qu'il franchit la bande de résistance
# Enfin on obtient un dataframe avec des valeurs True ou False, quand on a un True ça signifie
# que le cour de bourse est plus élevé que la bande de résistance haute et donc qu'il est l'heure 
# d'acheter et quand on a un False celà signifie que le cours de bourse est plus faible que la bande
# de résistance haute, autrement dit il ne faut pas encore acheter. 
comparaison_colonnes = df_concat['High'] > df_concat['Résistance haute']
comparaison_colonnes = pd.DataFrame(comparaison_colonnes)


# Maintnenant pour + de clarté on renomme la colonne qui contient les valeurs True et False
# on lui donne le nom : "franchissement"
comparaison_colonnes.columns = ['franchissement']

# Ensuite on garde seulement les lignes avec la valeur True, autrement dit les lignes pour lesquelles
# le cour de l'action est plus élevé que la bande de résistance. 
df_franchissement = comparaison_colonnes[comparaison_colonnes['franchissement']==True]

# Sur le graphique de la cellule précédent on voit que la bande rouge est fortement percée aux environs
# du mois d'Avril, on va donc garder dans notre tableau seulement les valeurs du mois d'avril
# pour trouver la date précise à laquelle ce franchissement important a eu lieu, autrement dit
# le franchissement qui nous donnait l'indication d'achat 
# Pour faire celà il faut tout d'abord convertir les dates en format spécial datetime
df_franchissement['Date'] = pd.to_datetime(df_franchissement.index)
df_franchissement[df_franchissement['Date'].dt.month == 4]
# On voit que c'est le 26 avril que le franchissement puissant démarre et donc qu'il fallait acheter
# l'action google

df_achat = df_franchissement[df_franchissement['Date'].dt.month == 4]

# la date d'achat codée en dur
date_ok = '2024-04-26 00:00:00-04:00'
# on la transforme ensuite en format datetime
date_ok = pd.to_datetime(date_ok)
df_cours_de_bourse = pd.DataFrame(data['High'])
# on localise le cour qui correspond à cette date
valeur_achat = df_cours_de_bourse.loc[date_ok, 'High']


# On dessine le graohique
plt.figure(figsize=(10, 6))
plt.plot(data.index, data['High'], label='Prix Haut', color='black') 
plt.plot(data.index, resistance_haute, linestyle='-', color='red', label='Ligne Haute de Support')
plt.xlabel('Date')
plt.ylabel('Cour')
plt.title(f"Lignes de Support pour {symbole}")
plt.legend()

# On annote le graphique avec une flèche 
plt.annotate(
    f"Acheter le {date_ok}",
    xy=(date_ok, valeur_achat-12), 
    xytext=(date_ok, valeur_achat-30), 
    arrowprops=dict(facecolor='green', shrink=0.05),
    fontsize=12,
    color='green'
)


plt.show()
